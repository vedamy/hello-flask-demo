# %% [markdown]
# # Week-21 Group Activity

# %% [markdown]
# 1. Make sure you can get the API from class to work in Azure. Take a screenshot of it
# working and add the image to a jupyter notebook.

# %% [markdown]
# ### Initial Hello World page deployed successfully

# %% [markdown]
# ![hello_world.png](attachment:hello_world.png)

# %% [markdown]
# ### complete us-gdp data deployed sucessfully

# %% [markdown]
# ![us-gdp-final.png](attachment:us-gdp-final.png)

# %% [markdown]
# 2. Loop through the API data in python using the /gdp/<year> endpoint for your API. What
# does it look like? Is there a way to alter the html page to simplify what you see?

# %% [markdown]
# We can alter the html page to simplify the data, I tried to Loop through Data to display the list of US GDP for better view.

# %% [markdown]
# #### Below is the code and image to display the list of US GDP for better view.

# %% [markdown]
# ![data.png](attachment:data.png)

# %% [markdown]
# ![year_sorted.png](attachment:year_sorted.png)
